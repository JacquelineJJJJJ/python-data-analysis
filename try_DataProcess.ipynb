# %%
import pandas as pd
# Out:
# C:\Users\jiyin\AppData\Local\Temp\ipykernel_25008\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\jiyin\\Desktop'

# %%
df=pd.read_csv("./1-01-1-按钮.csv")
df
# Out:
#             Time CoG Acceleration/X CoG Acceleration/Y CoG Acceleration/Z  \
# 0              s               m/s²               m/s²               m/s²
# 1              0           0.395375          -4.16E-09          -0.816291
# 2      0.0100001           0.395375          -4.16E-09          -0.816291
# 3      0.0200002            1.11984           1.97E-10          -0.781554
# 4      0.0300003             1.5289           9.41E-11          -0.726872
# ...          ...                ...                ...                ...
# 16026    160.251           -0.32902           0.198945        -0.00135692
# 16027    160.261          -0.328996           0.199028        -0.00140164
# 16028    160.271          -0.328977           0.199108        -0.00142629
# 16029    160.281          -0.328954           0.199189         -0.0014433
# 16030    160.291          -0.328926           0.199266        -0.00147089
#
#        Actual Gear Ratio Brake pedal force  Gas pedal Steering wheel angle  \
# ...

# %%
df.rename(columns={"Time":"Time(s)","CoG Acceleration/X":"Acc/X(m/s)","Steering wheel angle":"Steering wheel angle(°)","Speed/X":"Speed/X(km/h)","Lane gap":"lane gap(m)"},inplace=True)
df=df.drop([0])
df
# Out:
#          Time(s) Acc/X(m/s) CoG Acceleration/Y CoG Acceleration/Z  \
# 1              0   0.395375          -4.16E-09          -0.816291
# 2      0.0100001   0.395375          -4.16E-09          -0.816291
# 3      0.0200002    1.11984           1.97E-10          -0.781554
# 4      0.0300003     1.5289           9.41E-11          -0.726872
# 5      0.0400004    1.73171           4.73E-11          -0.646262
# ...          ...        ...                ...                ...
# 16026    160.251   -0.32902           0.198945        -0.00135692
# 16027    160.261  -0.328996           0.199028        -0.00140164
# 16028    160.271  -0.328977           0.199108        -0.00142629
# 16029    160.281  -0.328954           0.199189         -0.0014433
# 16030    160.291  -0.328926           0.199266        -0.00147089
#
#        Actual Gear Ratio Brake pedal force  Gas pedal Steering wheel angle(°)  \
# 1                    1.0                 0        0.0                       0
# ...

# %%
# 找缺失值
#找到具体的缺失值所在的行
rows_with_missing_values = df[df.isnull().any(axis=1)]
print(rows_with_missing_values)
# Out:
# Empty DataFrame
# Columns: [Time(s), Acc/X(m/s), CoG Acceleration/Y, CoG Acceleration/Z, Actual Gear Ratio, Brake pedal force, Gas pedal, Steering wheel angle(°), Speed/X(km/h), Speed/Y, Speed/Z, lane gap(m), Road gap]
# Index: []

# %%
df = df.astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16030 entries, 1 to 16030
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Time(s)                  16030 non-null  float64
#  1   Acc/X(m/s)               16030 non-null  float64
#  2   CoG Acceleration/Y       16030 non-null  float64
#  3   CoG Acceleration/Z       16030 non-null  float64
#  4   Actual Gear Ratio        16030 non-null  float64
#  5   Brake pedal force        16030 non-null  float64
#  6   Gas pedal                16030 non-null  float64
#  7   Steering wheel angle(°)  16030 non-null  float64
#  8   Speed/X(km/h)            16030 non-null  float64
#  9   Speed/Y                  16030 non-null  float64
#  10  Speed/Z                  16030 non-null  float64
#  11  lane gap(m)              16030 non-null  float64
#  12  Road gap                 16030 non-null  float64
# dtypes: float64(13)
# memory usage: 1.6 MB

# %%
df
# Out:
#        Time(s)  Acc/X(m/s)  CoG Acceleration/Y  CoG Acceleration/Z  \
# 1        0.000    0.395375       -4.160000e-09           -0.816291
# 2        0.010    0.395375       -4.160000e-09           -0.816291
# 3        0.020    1.119840        1.970000e-10           -0.781554
# 4        0.030    1.528900        9.410000e-11           -0.726872
# 5        0.040    1.731710        4.730000e-11           -0.646262
# ...        ...         ...                 ...                 ...
# 16026  160.251   -0.329020        1.989450e-01           -0.001357
# 16027  160.261   -0.328996        1.990280e-01           -0.001402
# 16028  160.271   -0.328977        1.991080e-01           -0.001426
# 16029  160.281   -0.328954        1.991890e-01           -0.001443
# 16030  160.291   -0.328926        1.992660e-01           -0.001471
#
#        Actual Gear Ratio  Brake pedal force  Gas pedal  \
# 1                    1.0                0.0        0.0
# ...

# %%
df.describe()
# Out:
#             Time(s)    Acc/X(m/s)  CoG Acceleration/Y  CoG Acceleration/Z  \
# count  16030.000000  16030.000000        16030.000000        16030.000000
# mean      80.145663      0.165895            0.007391           -0.001102
# std       46.276391      0.541984            0.332065            0.020284
# min        0.000000     -1.949800           -1.458550           -0.816291
# 25%       40.072900     -0.102472           -0.130095           -0.002088
# 50%       80.145700      0.066278            0.010782           -0.000407
# 75%      120.218500      0.218229            0.149068            0.000406
# max      160.291000      6.495010            2.107300            0.325692
#
#        Actual Gear Ratio  Brake pedal force     Gas pedal  \
# count       16030.000000            16030.0  16030.000000
# mean            4.896756                0.0      0.156411
# std             1.295653                0.0      0.124102
# min             1.000000                0.0      0.000000
# ...
